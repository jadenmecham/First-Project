# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


# Time resolution
dt = 0.01
t = np.arange(0, 10, dt)

# Piecewise function initialization
y = np.zeros_like(t)

# Define segments based on the time intervals
# 0 to 1 sec: constant at 0
y[(t >= 0) & (t < 1)] = 0

# 1 to 2 sec: constant increase (linear)
y[(t >= 1) & (t < 2)] = (t[(t >= 1) & (t < 2)] - 1) * 2  # Slope = 2

# 2 to 3 sec: constant
y[(t >= 2) & (t < 3)] = 2  # Continues from end of previous segment

# 3 to 5 sec: sine wave
y[(t >= 3) & (t < 5)] = 2 + np.sin(2 * np.pi * (t[(t >= 3) & (t < 5)] - 3))

# 5 to 6 sec: constant
y[(t >= 5) & (t < 6)] = 2  # Midpoint of sine wave is 2

# 6 to 8 sec: exponential decay
y[(t >= 6) & (t < 8)] = 2 * np.exp(-(t[(t >= 6) & (t < 8)] - 6))

# 8 to 10 sec: constant increase again (linear)
y[(t >= 8) & (t <= 10)] = 2 + (t[(t >= 8) & (t <= 10)] - 8) * 1.5  # Slope = 1.5

# Plotting
plt.figure(figsize=(10, 5))
plt.plot(t, y, label='Piecewise Function', color='blue')
plt.xlabel('Time (s)')
plt.ylabel('Velocity')
plt.grid(True)
# plt.legend()
plt.tight_layout()
plt.show()
# This code generates a piecewise function with different behaviors over specified time intervals.
